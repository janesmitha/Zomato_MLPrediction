# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data/deliverypred.csv')

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
#Drop ID, DeliveryPerson_ID,Restaurant_latitude,Restaurant_longitude,Delivery_location_latitude,Delivery_location_longitude,Order_Date
#Those are non factors for training our model
data.drop(columns=['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude','Order_Date'],inplace=True)
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd Time_Order_picked
# 0                 36.0                      4.2       21:55             22:10  \
# 1                 21.0                      4.7       14:55             15:05
# 2                 23.0                      4.7       17:30             17:40
# 3                 34.0                      4.3       09:20             09:30
# 4                 24.0                      4.7       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
#Ckeck for missing values

check_missing=data.isnull().sum()*100/data.shape[0]
check_missing[check_missing>0].sort_values(ascending=False)
# Out:
# Delivery_person_Ratings    4.185679
# Delivery_person_Age        4.067217
# Time_Orderd                3.797385
# City                       2.632503
# multiple_deliveries        2.178396
# Weather_conditions         1.351351
# Road_traffic_density       1.318445
# Festival                   0.500176
# dtype: float64

# %%
#Checking for no of unique values on object datatype
data.select_dtypes(include='object').nunique()
# Out:
# Time_Orderd             176
# Time_Order_picked       193
# Weather_conditions        6
# Road_traffic_density      4
# Type_of_order             4
# Type_of_vehicle           4
# Festival                  2
# City                      3
# dtype: int64

# %%
#Statistical representation of the dataset
data.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition
# count         43730.000000             43676.000000       45584.000000  \
# mean             29.566911                 4.633774           1.023385
# std               5.815064                 0.334744           0.839055
# min              15.000000                 1.000000           0.000000
# 25%              25.000000                 4.500000           0.000000
# 50%              30.000000                 4.700000           1.000000
# 75%              35.000000                 4.900000           2.000000
# max              50.000000                 6.000000           3.000000
#
#        multiple_deliveries  Time_taken (min)
# count         44591.000000      45584.000000
# mean              0.744635         26.293963
# std               0.572510          9.384298
# min               0.000000         10.000000
# 25%               0.000000         19.000000
# 50%               1.000000         26.000000
# 75%               1.000000         32.000000
# max               3.000000         54.000000

# %%
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd Time_Order_picked
# 0                 36.0                      4.2       21:55             22:10  \
# 1                 21.0                      4.7       14:55             15:05
# 2                 23.0                      4.7       17:30             17:40
# 3                 34.0                      4.3       09:20             09:30
# 4                 24.0                      4.7       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
data['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny', nan],
#       dtype=object)

# %%
# Dropping Nul Values from the dataset
data.dropna(axis=0,how='any',inplace=True)
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd Time_Order_picked
# 0                 36.0                      4.2       21:55             22:10  \
# 1                 21.0                      4.7       14:55             15:05
# 2                 23.0                      4.7       17:30             17:40
# 3                 34.0                      4.3       09:20             09:30
# 4                 24.0                      4.7       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City
# 0      motorcycle                  3.0       No  Metropolitian  \
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
#The Cities order more
plt.figure(figsize=(10,5))
data['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
#The items order are all sorts and almost equal proportions 
plt.figure(figsize=(10,5))
data['Type_of_order'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type_of_order'>

# %%
#The Orders are more on non festival days right !
plt.figure(figsize=(10,5))
data['Festival'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Festival'>

# %%
#Check for unique values on object datatype
data.select_dtypes(include='object').nunique()
# Out:
# Time_Orderd             176
# Time_Order_picked       193
# Weather_conditions        6
# Road_traffic_density      4
# Type_of_order             4
# Type_of_vehicle           3
# Festival                  2
# City                      3
# dtype: int64

# %% [markdown]
# EXPLORATORYDATAANALYSIS

# %%
#lIST OF CATEGORIAL VARIABLES TO PLOT

cat_vars=['Time_Orderd','Time_Order_picked','Weather_conditions','Road_traffic_density','Type_of_order','Type_of_vehicle','Festival','City']

# Create figure with subplots

fig,axs=plt.subplots(nrows=4,ncols=2,figsize=(20,20))
axs=axs.flatten()

#create barplot for each catagorial variable

for i, var in enumerate(cat_vars):
    sns.barplot(x=var,y='Time_taken (min)',data=data,ax=axs[i],estimator=np.mean)
axs[i].set_xticklabels(axs[i].get_xticklabels(),rotation=90)
    
fig.delaxes(axs[7])    
fig.tight_layout()
plt.show()

# %%
#graphical representation of the time todeliver on hue type of order
sns.set_style('darkgrid')
sns.set_palette('Set2')

sns.lineplot(x='Time_Orderd',y='Time_taken (min)',hue='Type_of_order',data=data,errorbar=None)

plt.title('Minimum Time Taken for Delivery ')
plt.xlabel('Time Orderd')
plt.ylabel('Time Taken')

plt.show()

# %%
label encoding for object datatype

# %%
# Loop over each coulmn in the DataFrame where the data type is object

for col in data.select_dtypes(include=['object']).columns:
    
    #Print the column name and unique value
    print(f"{col}: {data[col].unique()}")
# Out:
# Time_Orderd: ['21:55' '14:55' '17:30' '09:20' '19:50' '20:25' '20:30' '21:15' '20:20'
#  '22:30' '08:15' '19:30' '12:25' '18:35' '20:35' '23:20' '21:20' '23:35'
#  '22:35' '23:25' '13:35' '21:35' '18:55' '14:15' '0.458333333' '09:45'
#  '08:40' '0.958333333' '17:25' '19:45' '19:10' '10:55' '21:40'
#  '0.791666667' '16:45' '11:30' '15:10' '22:45' '22:10' '20:45' '22:50'
#  '17:55' '20:15' '22:25' '22:40' '23:50' '15:25' '10:20' '20:55' '10:40'
#  '15:55' '20:10' '12:10' '15:30' '10:35' '21:10' '20:50' '12:35' '0.875'
#  '23:40' '18:15' '18:20' '11:45' '12:45' '23:30' '10:50' '21:25' '10:10'
#  '17:50' '22:20' '12:40' '23:55' '10:25' '08:45' '23:45' '19:55' '22:15'
#  '23:10' '18:25' '18:45' '16:50' '1' '14:20' '10:15' '08:50' '0.375'
#  '17:45' '16:35' '08:30' '21:45' '14:50' '18:10' '12:20' '12:50' '09:10'
#  '12:30' '17:10' '19:15' '20:40' '17:20' '18:30' '13:10' '19:35' '09:50'
#  '0.833333333' '10:30' '09:40' '15:35' '16:55' '22:55' '0.666666667'
#  '0.75' '17:15' '21:30' '18:40' '11:10' '13:50' '21:50' '11:50'
#  '0.916666667' '08:25' '11:20' '11:55' '09:30' '08:20' '08:10' '11:40'
#  '23:15' '19:20' '13:30' '12:15' '09:25' '11:35' '0.416666667' '0.625'
#  '17:35' '17:40' '14:40' '18:50' '11:25' '19:40' '14:25' '0.5' '16:10'
#  '19:25' '08:55' '13:40' '0.708333333' '09:35' '08:35' '11:15' '16:15'
#  '09:15' '13:20' '15:50' '15:20' '16:20' '14:30' '15:45' '0.541666667'
#  '12:55' '10:45' '13:25' '09:55' '15:15' '13:15' '0.583333333' '15:40'
#  '16:25' '14:10' '13:45' '13:55' '16:40' '14:35' '16:30' '14:45']
# Time_Order_picked: ['22:10' '15:05' '17:40' '09:30' '20:05' '20:35' '15:10' '20:40' '21:30'
#  '20:25' '22:45' '08:30' '19:45' '12:30' '18:50' '23:30' '21:35' '23:45'
#  '22:50' '22:40' '23:35' '13:40' '21:45' '19:10' '14:25' '11:10' '09:55'
#  '08:55' '23:10' '17:30' '19:50' '19:25' '0.458333333' '19:15' '16:55'
#  '11:40' '15:15' '22:55' '22:25' '20:55' '23:05' '0.75' '0.958333333'
#  '20:50' '20:20' '22:35' '0.916666667' '23:55' '15:40' '10:30' '0.875'
#  '10:50' '16:05' '20:15' '12:15' '15:45' '22:15' '10:45' '24:05:00'
#  '21:25' '12:45' '21:15' '18:20' '18:25' '11:50' '12:50' '10:55' '21:40'
#  '10:20' '17:55' '23:50' '12:55' '24:10:00' '10:40' '0.375' '20:45'
#  '0.833333333' '23:15' '18:35' '22:20' '21:05' '0.708333333' '24:15:00'
#  '21:20' '14:35' '10:25' '09:05' '16:50' '08:40' '23:40' '21:50' '0.625'
#  '10:35' '09:25' '17:20' '19:30' '17:25' '20:10' '1' '17:35' '0.791666667'
#  '19:05' '13:20' '18:05' '19:20' '10:05' '09:10' '21:55' '19:40' '18:10'
#  '09:50' '15:50' '18:30' '18:15' '16:15' '11:15' '21:10' '15:30' '22:30'
#  '15:20' '23:20' '11:25' '13:55' '18:45' '22:05' '11:55' '18:55' '18:40'
#  '09:45' '17:15' '12:05' '0.5' '19:35' '08:25' '11:05' '12:40' '12:25'
#  '08:20' '23:25' '16:10' '17:50' '13:45' '08:15' '08:45' '09:40' '20:30'
#  '08:50' '14:45' '17:45' '0.416666667' '08:35' '19:55' '11:35' '11:20'
#  '14:30' '12:10' '10:15' '17:05' '10:10' '11:30' '16:25' '13:35' '09:15'
#  '15:55' '0.541666667' '15:35' '13:10' '13:05' '11:45' '09:35' '16:20'
#  '16:30' '16:45' '09:20' '13:25' '14:15' '16:35' '16:40' '14:05' '13:30'
#  '14:40' '12:20' '13:50' '17:10' '14:20' '12:35' '0.583333333' '14:10'
#  '15:25' '14:55' '13:15' '14:50' '0.666666667']
# Weather_conditions: ['Fog' 'Stormy' 'Sandstorms' 'Windy' 'Cloudy' 'Sunny']
# Road_traffic_density: ['Jam' 'High' 'Medium' 'Low']
# Type_of_order: ['Snack' 'Meal' 'Drinks' 'Buffet']
# Type_of_vehicle: ['motorcycle' 'scooter' 'electric_scooter']
# Festival: ['No' 'Yes']
# City: ['Metropolitian' 'Urban' 'Semi-Urban']

# %%
data.dtypes
# Out:
# Delivery_person_Age        float64
# Delivery_person_Ratings    float64
# Time_Orderd                 object
# Time_Order_picked           object
# Weather_conditions          object
# Road_traffic_density        object
# Vehicle_condition            int64
# Type_of_order               object
# Type_of_vehicle             object
# multiple_deliveries        float64
# Festival                    object
# City                        object
# Time_taken (min)             int64
# dtype: object

# %%
from sklearn import preprocessing
# Loop over each coulmn in the DataFrame where the data type is object

for col in data.select_dtypes(include=['object']).columns:
#Initialize the label coder
    label_encoder=preprocessing.LabelEncoder()

#Fit the encoder to the unique value in the column
    label_encoder.fit(data[col].unique())

#Transform the column using encoder

    data[col]=label_encoder.transform(data[col])

#Print the column name and unique encoded values

    print(f"{col}:{data[col].unique()}")
# Out:
# Time_Orderd:[155  85 110  27 134 139 140 147 138 160  16 130  59 121 141 168 148 171
#  161 169  71 151 125  77   2  32  21  14 109 133 126  45 152  10 103  50
#   86 163 156 143 164 115 137 159 162 174  89  38 145  42  95 136  56  90
#   41 146 144  61  12 172 117 118  53  63 170  44 149  36 114 158  62 175
#   39  22 173 135 157 166 119 123 104  35  78  37  23   0 113 101  19 153
#   84 116  58  64  25  60 106 127 142 108 120  66 131  33  11  40  31  91
#  105 165   7   9 107 150 122  46  74 154  54  13  18  48  55  29  17  15
#   52 167 128  70  57  28  51   1   6 111 112  82 124  49 132  79   3  96
#  129  24  72   8  30  20  47  97  26  68  94  88  98  80  93   4  65  43
#   69  34  87  67   5  92  99  76  73  75 102  81 100  83]
# Time_Order_picked:[169  91 120  29 146 152  92 153 162 150 176  18 143  63 133 184 163 187
#  177 175 185  76 165 136  84  48  34  23 180 118 144 139   2 137 112  54
#   93 178 172 156 179   9  14 155 149 174  13 189  98  41  12  45 102 148
#   60  99 170  44 190 161  66 159 127 128  56  67  46 164  39 123 188  68
#  191  43   0 154  11 181 130 171 157   8 192 160  86  40  24 111  20 186
#  166   6  42  28 116 140 117 147  35 119  10 135  72 124 138  36  25 167
#  142 125  33 100 129 126 104  49 158  96 173  94 182  51  79 132 168  57
#  134 131  32 115  58   3 141  17  47  65  62  16 183 103 122  77  15  21
#   31 151  22  88 121   1  19 145  53  50  85  59  38 113  37  52 106  75
#   26 101   4  97  70  69  55  30 105 107 110  27  73  82 108 109  80  74
#   87  61  78 114  83  64   5  81  95  90  71  89   7]
# Weather_conditions:[1 3 2 5 0 4]
# Road_traffic_density:[1 0 3 2]
# Type_of_order:[3 2 1 0]
# Type_of_vehicle:[1 2 0]
# Festival:[0 1]
# City:[0 2 1]

# %%
data.dtypes
# Out:
# Delivery_person_Age        float64
# Delivery_person_Ratings    float64
# Time_Orderd                  int32
# Time_Order_picked            int32
# Weather_conditions           int32
# Road_traffic_density         int32
# Vehicle_condition            int64
# Type_of_order                int32
# Type_of_vehicle              int32
# multiple_deliveries        float64
# Festival                     int32
# City                         int32
# Time_taken (min)             int64
# dtype: object

# %%
ALL THE DATA IS CATEGORICAL THAT MEANS NO OUTLIER

# %%
#CORELATION HEATMAP

plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),fmt='.2g',annot=True)
# Out:
# <Axes: >
